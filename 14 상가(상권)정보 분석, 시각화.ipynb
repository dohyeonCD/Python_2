# %% [markdown]
# * 라이브러리 임포트

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams['font.family']='Malgun Gothic'
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# # 데이터 수집
# * 상가상권정보<br>
# https://www.data.go.kr/data/15083033/fileData.do

# %% [markdown]
# ## 데이터프레임 생성
# * 17개 파일의 데이터를 각각 데이터프레임으로 만든 후 합친다.

# %% [markdown]
# ### 17개의 파일을 각각 데이터프레임으로 만들기
# * column에 NaN값이나 여러 type의 데이터가 섞여 있으면 DtypeWarning 발생<br>
# dtype option으로 타입을 명시해주거나 low_memory = False로 지정해 주면 경고 메시지가 출력되지 않는다.

# %%
df1 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_강원_202109.csv',error_bad_lines=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12172\1585166895.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df1 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_강원_202109.csv',error_bad_lines=False)
# b'Skipping line 16489: expected 39 fields, saw 76\n'
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 df1 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_강원_202109.csv',error_bad_lines=False)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
# ...

# %%
df2 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_경기_202109.csv',error_bad_lines=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12172\632142833.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df2 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_경기_202109.csv',error_bad_lines=False)

# %%
df3 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_경남_202109.csv',error_bad_lines=False)

# %%
df4 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_경북_202109.csv',error_bad_lines=False)

# %%
df5 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_광주_202109.csv',error_bad_lines=False)

# %%
df6 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_대구_202109.csv',error_bad_lines=False)

# %%
df7 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_대전_202109.csv',error_bad_lines=False)

# %%
df8 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_부산_202109.csv',error_bad_lines=False)

# %%
df9 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_서울_202109.csv',error_bad_lines=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12172\3379867571.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df9 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_서울_202109.csv',error_bad_lines=False)
# b'Skipping line 31667: expected 39 fields, saw 48\n'
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 df9 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_서울_202109.csv',error_bad_lines=False)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
# ...

# %%
df10 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_세종_202109.csv',error_bad_lines=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12172\3079378863.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df10 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_세종_202109.csv',error_bad_lines=False)

# %%
df11 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_울산_202109.csv',error_bad_lines=False)

# %%
df12 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_인천_202109.csv',error_bad_lines=False)

# %%
df13 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_전남_202109.csv',error_bad_lines=False)

# %%
df14 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_전북_202109.csv',error_bad_lines=False)

# %%
df15 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_제주_202109.csv',error_bad_lines=False)

# %%
df16 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_충남_202109.csv',error_bad_lines=False)

# %%
df17 = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_충북_202109.csv',error_bad_lines=False)

# %% [markdown]
# ### 데이터프레임 연결하기
# * pd.concat(데이터프레임리스트) : 행 방향으로 연결
# * pd.concat(데이터프레임리스트, axis=1) : 열 방향으로 연결
# * 인덱스 재지정 : ignore_index = True

# %%
# 데이터프레임 합치기 : [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17]  되는 거 2,10
df= pd.concat([df2,df10], ignore_index=True)

# %%
len(df.columns)
# Out:
# 39

# %%
# 컬럼갯수 최대 지정 ...말고 다 보기
pd.options.display.max_columns=39

# %%
df.head(1)
# Out:
#      상가업소번호      상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 0  20713599  눈높이러닝센타  NaN         R    학문/교육       R13   학문교육기타    R13A01
#
#   상권업종소분류명 표준산업분류코드   표준산업분류명  시도코드  시도명  시군구코드 시군구명       행정동코드  행정동명  \
# 0    학습지보급   P85503  방문 교육 학원    41  경기도  41210  광명시  4121054000  광명3동
#
#           법정동코드 법정동명                 지번코드  대지구분코드 대지구분명  지번본번지  지번부번지  \
# 0  4.121010e+09  광명동  4121010100101490006       1    대지    149    6.0
#
#                 지번주소         도로명코드          도로명  건물본번지  건물부번지  \
# 0  경기도 광명시 광명동 149-6  412103000022  경기도 광명시 오리로    946    NaN
#
#                       건물관리번호  건물명            도로명주소     구우편번호    신우편번호  동정보  \
# 0  4121010100101490006003352  NaN  경기도 광명시 오리로 946  423010.0  14221.0  NaN
#
#    층정보 호정보          경도        위도
# 0  NaN   2  126.858147  37.47853

# %% [markdown]
# # 데이터 확인 및 전처리

# %% [markdown]
# ## 데이터 크기

# %%
df.shape
# Out:
# (528763, 39)

# %% [markdown]
# ## 데이터프레임 정보

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528763 entries, 0 to 528762
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     528763 non-null  int64
#  1   상호명        528763 non-null  object
#  2   지점명        90202 non-null   object
#  3   상권업종대분류코드  528763 non-null  object
#  4   상권업종대분류명   528763 non-null  object
#  5   상권업종중분류코드  528763 non-null  object
#  6   상권업종중분류명   528763 non-null  object
#  7   상권업종소분류코드  528763 non-null  object
#  8   상권업종소분류명   528763 non-null  object
#  9   표준산업분류코드   495524 non-null  object
#  10  표준산업분류명    495524 non-null  object
#  11  시도코드       528763 non-null  int64
#  12  시도명        528763 non-null  object
#  13  시군구코드      528763 non-null  int64
#  14  시군구명       528763 non-null  object
#  15  행정동코드      528763 non-null  int64
#  16  행정동명       522208 non-null  object
#  17  법정동코드      528542 non-null  float64
#  18  법정동명       528542 non-null  object
# ...

# %% [markdown]
# ## 서브셋 만들기

# %%
df.head(1)
# Out:
#      상가업소번호      상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 0  20713599  눈높이러닝센타  NaN         R    학문/교육       R13   학문교육기타    R13A01
#
#   상권업종소분류명 표준산업분류코드   표준산업분류명  시도코드  시도명  시군구코드 시군구명       행정동코드  행정동명  \
# 0    학습지보급   P85503  방문 교육 학원    41  경기도  41210  광명시  4121054000  광명3동
#
#           법정동코드 법정동명                 지번코드  대지구분코드 대지구분명  지번본번지  지번부번지  \
# 0  4.121010e+09  광명동  4121010100101490006       1    대지    149    6.0
#
#                 지번주소         도로명코드          도로명  건물본번지  건물부번지  \
# 0  경기도 광명시 광명동 149-6  412103000022  경기도 광명시 오리로    946    NaN
#
#                       건물관리번호  건물명            도로명주소     구우편번호    신우편번호  동정보  \
# 0  4121010100101490006003352  NaN  경기도 광명시 오리로 946  423010.0  14221.0  NaN
#
#    층정보 호정보          경도        위도
# 0  NaN   2  126.858147  37.47853

# %%
# 컬럼명 가져오기
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %% [markdown]
# ### 필요한 컬럼만 추출하여 서브셋 만들기
# * 서브셋을 만들 때는 copy()기능을 사용하는 것을 권장

# %%
df_store= df[['상호명','상권업종대분류명','상권업종중분류명','상권업종소분류명','시도명','시군구명','행정동명','법정동명','경도','위도']].copy()

# %%
df_store
# Out:
#                상호명 상권업종대분류명   상권업종중분류명   상권업종소분류명      시도명     시군구명  행정동명  \
# 0          눈높이러닝센타    학문/교육     학문교육기타      학습지보급      경기도      광명시  광명3동
# 1             유니베라       소매      화장품소매     화장품판매점      경기도  용인시 기흥구   구성동
# 2          엠아이케이21       소매  운동/경기용품소매    운동/경기용품      경기도  성남시 분당구   구미동
# 3        큰손의정부부대찌개       음식         한식  부대찌개/섞어찌개      경기도      김포시  김포본동
# 4              앞족애       음식         한식  한식/백반/한정식      경기도     의정부시  가능2동
# ...            ...      ...        ...        ...      ...      ...   ...
# 528758  약속공인중개사사무소      부동산      부동산중개      부동산중개  세종특별자치시  세종특별자치시   소담동
# 528759       제이갤러리       소매  취미/오락관련소매    그림/액자판매  세종특별자치시  세종특별자치시   연서면
# 528760      퍼니판해밀점       소매  사무/문구/컴퓨터    사무/문구용품  세종특별자치시  세종특별자치시   도담동
# 528761     메타국어교습소    학문/교육      학원-어학  학원-외국어/어학  세종특별자치시  세종특별자치시   보람동
# 528762          숯숯       음식         한식     갈비/삼겹살  세종특별자치시  세종특별자치시   연서면
#
#        법정동명          경도         위도
# 0       광명동  126.858147  37.478530
# ...

# %% [markdown]
# ### 서브셋 데이터 확인

# %%
# 데이터 크기
df_store.shape
# Out:
# (528763, 10)

# %%
# 데이터 정보(메모리 용량)
df_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528763 entries, 0 to 528762
# Data columns (total 10 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   상호명       528763 non-null  object
#  1   상권업종대분류명  528763 non-null  object
#  2   상권업종중분류명  528763 non-null  object
#  3   상권업종소분류명  528763 non-null  object
#  4   시도명       528763 non-null  object
#  5   시군구명      528763 non-null  object
#  6   행정동명      522208 non-null  object
#  7   법정동명      528542 non-null  object
#  8   경도        528763 non-null  float64
#  9   위도        528763 non-null  float64
# dtypes: float64(2), object(8)
# memory usage: 40.3+ MB

# %% [markdown]
# ### 결측치분석/처리

# %%
df_store.isnull().sum()
# Out:
# 상호명            0
# 상권업종대분류명       0
# 상권업종중분류명       0
# 상권업종소분류명       0
# 시도명            0
# 시군구명           0
# 행정동명        6555
# 법정동명         221
# 경도             0
# 위도             0
# dtype: int64

# %% [markdown]
# ## 상권업종분류

# %%
df_store['상권업종대분류명'].unique()
# Out:
# array(['학문/교육', '소매', '음식', '생활서비스', '숙박', '관광/여가/오락', '부동산', '스포츠'],
#       dtype=object)

# %%
df_store['상권업종대분류명'].nunique()
# Out:
# 8

# %%
df_store['상권업종중분류명'].unique()
# Out:
# array(['학문교육기타', '화장품소매', '운동/경기용품소매', '한식', '철물/난방/건설자재소매',
#        '사진/광학/정밀기기소매', '자동차/이륜차', '음/식료품소매', '물품기기대여', '이/미용/건강', '주택수리',
#        '캠프/별장/펜션', '모텔/여관/여인숙', '사무/문구/컴퓨터', '분식', '선물/팬시/기념품', '종합소매점',
#        '의복의류', '학원-음악미술무용', '자동차/자동차용품', '유흥주점', '무도/유흥/가무', '건강/미용식품',
#        '학원-어학', '일식/수산물', '분양', '양식', '취미/오락관련소매', '의약/의료품소매', '중고품소매/교환',
#        '책/서적/도서', '부동산중개', '닭/오리요리', '실내운동시설', '학원-보습교습입시', '중식',
#        '대중목욕탕/휴게', '도서관/독서실', '제과제빵떡케익', '기타판매업', '별식/퓨전요리', '가정/주방/인테리어',
#        '세탁/가사서비스', '호텔/콘도', '광고/인쇄', '학원기타', '학원-예능취미체육', '패스트푸드', '부페',
#        'PC/오락/당구/볼링등', '실외운동시설', '페인트/유리제품소매', '요가/단전/마사지', '가구소매',
#        '주유소/충전소', '민박/하숙', '운영관리시설', '사진', '가방/신발/액세서리', '유아교육', '커피점/카페',
#        '운송/배달/택배', '개인/가정용품수리', '놀이/여가/취미', '대행업', '음식배달서비스', '연극/영화/극장',
#        '가전제품소매', '애견/애완/동물', '기타음식업', '인력/고용/용역알선', '예술품/골동품/수석/분재',
#        '시계/귀금속소매', '개인서비스', '학원-컴퓨터', '유아용품', '기타서비스업', '장례/묘지',
# ...

# %%
df_store['상권업종중분류명'].nunique()
# Out:
# 88

# %%
df_store['상권업종소분류명'].nunique()
# Out:
# 667

# %% [markdown]
# ### 상권업종분류표

# %%
df_store_class= df_store[['상권업종대분류명','상권업종중분류명','상권업종소분류명']].drop_duplicates().sort_values(['상권업종대분류명','상권업종중분류명','상권업종소분류명'])

# %%
# 상권업종 분류표 모두보기(최대 행 수 지정)
pd.options.display.max_rows=20

# %%
df_store_class
# Out:
#        상권업종대분류명      상권업종중분류명 상권업종소분류명
# 588    관광/여가/오락  PC/오락/당구/볼링등       기원
# 165    관광/여가/오락  PC/오락/당구/볼링등      당구장
# 1506   관광/여가/오락  PC/오락/당구/볼링등      볼링장
# 793    관광/여가/오락  PC/오락/당구/볼링등   비디오감상실
# 23224  관광/여가/오락  PC/오락/당구/볼링등   오락용사격장
# ...         ...           ...      ...
# 35146     학문/교육          학원기타    학원-모델
# 58823     학문/교육          학원기타  학원-실내운전
# 4182      학문/교육          학원기타  학원-심리변론
# 56976     학문/교육          학원기타    학원-역학
# 9856      학문/교육          학원기타    학원-침술
#
# [667 rows x 3 columns]

# %% [markdown]
# # 전국 상가 등록 현황

# %% [markdown]
# ## 업종 대분류별 상가 갯수

# %%
df_store_class1= df_store['상권업종대분류명'].value_counts()
df_store_class1
# Out:
# 음식          179794
# 소매          168851
# 생활서비스        88669
# 학문/교육        42379
# 부동산          25015
# 관광/여가/오락     11833
# 스포츠           6565
# 숙박            5657
# Name: 상권업종대분류명, dtype: int64

# %%
fig= plt.figure(figsize=(10,5), facecolor='snow')

# 막대그래프
plt.subplot(121)
plt.bar(df_store_class1.index, df_store_class1.values)
plt.xticks(rotation=45)
plt.grid(axis='y', ls=':')

# 파이그래프
plt.subplot(122)
plt.pie(df_store_class1.values, labels=df_store_class1.index, autopct='%.1f%%', pctdistance=0.8, wedgeprops={'width':0.6})

fig.suptitle('전국 업종별 상가등록 현황', size=20)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 시도별 상가 갯수

# %%
df_store_sido= df_store['시도명'].value_counts()
df_store_sido
# Out:
# 경기도        516790
# 세종특별자치시     11973
# Name: 시도명, dtype: int64

# %%
fig= plt.figure(figsize=(10,5), facecolor='snow')

# 막대그래프
plt.subplot(121)
plt.bar(df_store_sido.index, df_store_sido.values)
plt.grid(axis='y', ls=':')

# 파이그래프
plt.subplot(122)
plt.pie(df_store_sido.values, labels=df_store_sido.index, autopct='%.1f%%', pctdistance=0.8, wedgeprops={'width':0.6})

fig.suptitle('전국 시도별 상가등록 현황', size=20)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 시도별 업종대분류별 상가 현황

# %%
df_store_pivot= df_store.pivot_table(index='상권업종대분류명', columns='시도명', values='상호명', aggfunc='count')
df_store_pivot
# Out:
# 시도명          경기도  세종특별자치시
# 상권업종대분류명
# 관광/여가/오락   11607      226
# 부동산        24092      923
# 생활서비스      86978     1691
# 소매        165832     3019
# 숙박          5595       62
# 스포츠         6429      136
# 음식        174824     4970
# 학문/교육      41433      946

# %%
plt.figure(figsize=(15,5))
sns.heatmap(data=df_store_pivot, cmap='Blues', annot=True, fmt='d')
plt.show()

# %% [markdown]
# # 서울특별시 상가 현황

# %%
df_store_gi= df_store[df_store['시도명']=='경기도'].copy()
df_store_gi
# Out:
#               상호명 상권업종대분류명   상권업종중분류명   상권업종소분류명  시도명      시군구명   행정동명  법정동명  \
# 0         눈높이러닝센타    학문/교육     학문교육기타      학습지보급  경기도       광명시   광명3동   광명동
# 1            유니베라       소매      화장품소매     화장품판매점  경기도   용인시 기흥구    구성동   언남동
# 2         엠아이케이21       소매  운동/경기용품소매    운동/경기용품  경기도   성남시 분당구    구미동   구미동
# 3       큰손의정부부대찌개       음식         한식  부대찌개/섞어찌개  경기도       김포시   김포본동   감정동
# 4             앞족애       음식         한식  한식/백반/한정식  경기도      의정부시   가능2동   가능동
# ...           ...      ...        ...        ...  ...       ...    ...   ...
# 516785     스튜디오독독    생활서비스         사진        사진관  경기도   성남시 중원구  상대원3동  상대원동
# 516786    아로마포레스트       소매      화장품소매      향수전문점  경기도  고양시 일산서구    탄현동   탄현동
# 516787      야당핫헤어    생활서비스    이/미용/건강      여성미용실  경기도       파주시   운정3동   야당동
# 516788  산성풍천장어직판장       음식         한식  한식/백반/한정식  경기도   성남시 중원구   은행2동   은행동
# 516789        꽃다방       음식         한식  한식/백반/한정식  경기도  고양시 일산동구   장항2동   장항동
#
#                 경도         위도
# ...

# %% [markdown]
# ## 구별 상가 등록 현황

# %%
df_store_gi['시명']=df_store_gi['시군구명'].str.split(' ').str[0]
df_store_gi
# Out:
#               상호명 상권업종대분류명   상권업종중분류명   상권업종소분류명  시도명      시군구명   행정동명  법정동명  \
# 0         눈높이러닝센타    학문/교육     학문교육기타      학습지보급  경기도       광명시   광명3동   광명동
# 1            유니베라       소매      화장품소매     화장품판매점  경기도   용인시 기흥구    구성동   언남동
# 2         엠아이케이21       소매  운동/경기용품소매    운동/경기용품  경기도   성남시 분당구    구미동   구미동
# 3       큰손의정부부대찌개       음식         한식  부대찌개/섞어찌개  경기도       김포시   김포본동   감정동
# 4             앞족애       음식         한식  한식/백반/한정식  경기도      의정부시   가능2동   가능동
# ...           ...      ...        ...        ...  ...       ...    ...   ...
# 516785     스튜디오독독    생활서비스         사진        사진관  경기도   성남시 중원구  상대원3동  상대원동
# 516786    아로마포레스트       소매      화장품소매      향수전문점  경기도  고양시 일산서구    탄현동   탄현동
# 516787      야당핫헤어    생활서비스    이/미용/건강      여성미용실  경기도       파주시   운정3동   야당동
# 516788  산성풍천장어직판장       음식         한식  한식/백반/한정식  경기도   성남시 중원구   은행2동   은행동
# 516789        꽃다방       음식         한식  한식/백반/한정식  경기도  고양시 일산동구   장항2동   장항동
#
#                 경도         위도    시명
# ...

# %%
df_store_gi_si= df_store_gi['시명'].value_counts()
df_store_gi_si
# Out:
# 수원시     46180
# 성남시     37150
# 용인시     35623
# 고양시     32233
# 화성시     30502
#         ...
# 가평군      5183
# 동두천시     4853
# 의왕시      3414
# 연천군      2742
# 과천시      1784
# Name: 시명, Length: 31, dtype: int64

# %% [markdown]
# ## 판다스 함수로 시각화
# * 데이터프레임.plot.함수명

# %%
fig= plt.figure(figsize=(10,5))

plt.subplot(121)
#df_store_gi_si.plot(kind='bar')
df_store_gi_si.plot.bar(color='r')

plt.subplot(122)
df_store_gi_si.plot.pie(autopct='%.1f%%', pctdistance=0.8, wedgeprops={'width':0.6})

fig.suptitle('경기도 시별 상가등록 현황', size=20)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 구별/업종대분류별 상가 현황

# %% [markdown]
# ### 히트맵으로 시각화

# %%
df_store_gi_pivot= df_store_gi.pivot_table(index='상권업종대분류명', columns='시명', values='상호명', aggfunc='count')

# %%
plt.figure(figsize=(15,5))
sns.heatmap(df_store_gi_pivot, cmap='Purples', annot=True, fmt='d')
plt.show()

# %% [markdown]
# # 소분류-구별 상가 등록 수 시각화
# * scatter차트, hexbin으로 특정 소분류의 구별 상가 등록 수 시각화
# * 위도, 경도에 상가 위치 표시

# %% [markdown]
# ## 구별 위도, 경도 평균값

# %%
df_store_gi_location= df_store_gi[['시명','경도','위도']].groupby('시명').mean()
df_store_gi_location
# Out:
#              경도         위도
# 시명
# 가평군  127.452220  37.777594
# 고양시  126.805153  37.663052
# 과천시  127.002508  37.436488
# 광명시  126.868395  37.461400
# 광주시  127.259405  37.387710
# ..          ...        ...
# 파주시  126.772540  37.773574
# 평택시  127.043366  37.017488
# 포천시  127.208864  37.894565
# 하남시  127.197679  37.540453
# 화성시  126.958429  37.182907
#
# [31 rows x 2 columns]

# %% [markdown]
# ## 커피전문점/카페/다방 현황

# %%
plt.figure(figsize=(8,6))
df_store_gi_class3= df_store_gi[df_store_gi['상권업종소분류명']=='커피전문점/카페/다방']
df_store_gi_class3

sns.scatterplot(data=df_store_gi_class3, x='경도', y='위도', hue='시명', marker='.', alpha=0.3)
plt.legend(ncol=2, loc=(1.05,0.27))

for i in range(len(df_store_gi_location)):
    x= df_store_gi_location.iloc[i,0]
    y= df_store_gi_location.iloc[i,1]
    text= df_store_gi_location.index[i]
    plt.text(x,y,text, ha='center')

plt.title('커피전문점/카페/다방', size=20)
plt.show()

# %%
plt.figure(figsize=(8,6))
df_store_gi_class3= df_store_gi[df_store_gi['상권업종소분류명']=='커피전문점/카페/다방']
plt.hexbin(df_store_gi_class3['경도'], df_store_gi_class3['위도'], cmap='Blues', gridsize=30)

for i in range(len(df_store_gi_location)):
    x= df_store_gi_location.iloc[i,0]
    y= df_store_gi_location.iloc[i,1]
    text= df_store_gi_location.index[i]
    plt.text(x,y,text, ha='center')

plt.colorbar()
plt.title('커피전문점/카페/다방', size=20)
plt.show()

# %% [markdown]
# ## 여성미용실

# %%
plt.figure(figsize=(8,6))
df_store_gi_class3= df_store_gi[df_store_gi['상권업종소분류명']=='여성미용실']
plt.hexbin(df_store_gi_class3['경도'], df_store_gi_class3['위도'], cmap='Blues', gridsize=30)

for i in range(len(df_store_gi_location)):
    x= df_store_gi_location.iloc[i,0]
    y= df_store_gi_location.iloc[i,1]
    text= df_store_gi_location.index[i]
    plt.text(x,y,text, ha='center')

plt.colorbar()
plt.title('여성미용실', size=20)
plt.show()

# %% [markdown]
# ## 학원-입시

# %%
plt.figure(figsize=(8,6))
df_store_gi_class3= df_store_gi[df_store_gi['상권업종소분류명']=='학원-입시']
plt.hexbin(df_store_gi_class3['경도'], df_store_gi_class3['위도'], cmap='Blues', gridsize=30)

for i in range(len(df_store_gi_location)):
    x= df_store_gi_location.iloc[i,0]
    y= df_store_gi_location.iloc[i,1]
    text= df_store_gi_location.index[i]
    plt.text(x,y,text, ha='center')

plt.colorbar()
plt.title('학원-입시', size=20)
plt.show()

# %% [markdown]
# ## 어린이집

# %%
plt.figure(figsize=(8,6))
df_store_gi_class3= df_store_gi[df_store_gi['상권업종소분류명']=='어린이집']
plt.hexbin(df_store_gi_class3['경도'], df_store_gi_class3['위도'], cmap='Blues', gridsize=30)

for i in range(len(df_store_gi_location)):
    x= df_store_gi_location.iloc[i,0]
    y= df_store_gi_location.iloc[i,1]
    text= df_store_gi_location.index[i]
    plt.text(x,y,text, ha='center')

plt.colorbar()
plt.title('어린이집', size=20)
plt.show()
